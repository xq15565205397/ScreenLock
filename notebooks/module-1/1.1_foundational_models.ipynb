# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model
import os

model = init_chat_model(model="qwen-plus",model_provider="openai",base_url=os.getenv("ALIBABA_BASE_URL"))

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='The Moon doesn\'t have a capital because it is not a country or inhabited territory with a government. It\'s a natural satellite of Earth and currently has no permanent human settlements or political structure. While various countries and organizations have plans for lunar exploration and potential bases in the future, there is no official "capital of the Moon."', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 65, 'prompt_tokens': 16, 'total_tokens': 81, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'qwen-plus', 'system_fingerprint': None, 'id': 'chatcmpl-c96da94e-eba1-90c2-9d09-70ca93c528d8', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bcae9-ea87-7201-bca9-3f6f9ed847b9-0', usage_metadata={'input_tokens': 16, 'output_tokens': 65, 'total_tokens': 81, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})

# %%
print(response.content)
# Out:
# The Moon doesn't have a capital because it is not a country or a sovereign entity. It is a natural satellite of Earth and is not governed by any single nation. While various countries and space agencies have landed spacecraft on the Moon, no permanent human settlements or governments exist there yet. So, there is no capital city—or any cities, for that matter—on the Moon.

# %%
from pprint import pprint

pprint(response.response_metadata)

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='4be079e8-bdda-4ee4-aeb1-95483ec7b8e8'),
#               AIMessage(content="The Moon doesn't have a capital because it is not a country or inhabited territory with a government. It's a natural satellite of Earth and currently has no permanent human settlements or political structure. While several countries and organizations have sent missions to the Moon, there are no cities, capitals, or official governing bodies there.\n\nSo, in short: **the Moon has no capital**—but it’s a fascinating place for science and exploration! 🌕🚀", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 91, 'prompt_tokens': 16, 'total_tokens': 107, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'qwen-plus', 'system_fingerprint': None, 'id': 'chatcmpl-c37ca778-365e-90d4-9ba1-00cf1f7a1515', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bcaf6-15d0-7ee0-8c06-8aa363aabf02-0', usage_metadata={'input_tokens': 16, 'output_tokens': 91, 'total_tokens': 107, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
print(response['messages'][-1].content)
# Out:
# The Moon doesn't have a capital because it is not a country or inhabited territory with a government. It's a natural satellite of Earth and currently has no permanent human settlements or political structure. While several countries and organizations have sent missions to the Moon, there are no cities, capitals, or official governing bodies there.
#
# So, in short: **the Moon has no capital**—but it’s a fascinating place for science and exploration! 🌕🚀

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='c79b4013-24c5-410c-bd1e-0ff5436742d9'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='17801b6c-eb33-4111-9bc8-5ffa32f79131'),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='d6de76a6-1d02-49ef-bb32-03e5288355cc'),
#               AIMessage(content='Ah, I see where this is going—great question!\n\nHowever, I should clarify: **there is currently no capital of the Moon**, and **Luna City does not actually exist** (yet!). The Moon has no officially recognized cities, governments, or human settlements. It remains uninhabited by humans beyond temporary visits during crewed missions like NASA\'s Apollo program.\n\nThat said, "Luna City" is a popular concept in science fiction, futurism, and space exploration visions. In speculative and imaginative contexts, *Luna City* often refers to a hypothetical future lunar settlement—possibly the first permanent human colony on the Moon. Here’s what people *imagine* such a city might be like:\n\n🌕 **Location**: Often envisioned near the Moon’s south pole, where water ice exists in permanently shadowed craters—crucial for life support and fuel production.\n\n🏙️ **Design**: Built underground or under domes to protect inhabitants from radiation, micrometeorites, and extreme temperature swings. Structures might use 3D-printed regolith (lunar soil) for shielding.\n\n🔋 **Power**: Likely solar or nuclear, with possible expansion to helium-3 mining for future fusion energy.\n\n👨\u200d🚀 **Purpose**: A hub for scientific research, astronomical observation, testing deep-space technologies, and possibly a launch point for Mars missions.\n\n🌍 **Governance**: Under the **Outer Space Treaty (1967)**, no nation can claim sovereignty over the Moon. So any future Luna City would likely be governed by international agreement—perhaps a coalition of space agencies or a new legal framework.\n\nSo while *Luna City* isn’t real today… it might be one day! 🚀✨\n\nWould you like to explore what a real lunar base could look like, based on current plans by NASA, ESA, or SpaceX?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 377, 'prompt_tokens': 43, 'total_tokens': 420, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'qwen-plus', 'system_fingerprint': None, 'id': 'chatcmpl-01f663c8-1860-9d8e-9ec3-38e2e3117393', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bcaf6-e66c-7aa0-b7ea-8010bb6edf70-0', usage_metadata={'input_tokens': 43, 'output_tokens': 377, 'total_tokens': 420, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# As of now, **Luna City does not exist**—there is no permanent human settlement or capital city on the Moon, including a place officially named "Luna City."
#
# However, the concept of **Luna City** is a popular one in science fiction, futurism, and space exploration planning. Let’s explore both the fictional and real-world aspects:
#
# ---
#
# ### 🌕 What Is "Luna City"?
#
# **"Luna City"** is a hypothetical or fictional name often used to describe a future human settlement on the Moon—especially one that could serve as a central hub for lunar colonization. The term appears frequently in:
#
# - Science fiction novels (e.g., Robert A. Heinlein's *The Moon Is a Harsh Mistress*)
# - Futuristic space documentaries
# - Concept art by space agencies and private companies
#
# In these contexts, Luna City is imagined as:
# - A self-sustaining colony
# - Housing thousands of residents
# - Featuring domed habitats, underground tunnels, fusion reactors, hydroponic farms, and research centers
# - Possibly serving as a launch point for deeper space missions (e.g., to Mars)
#
# ---
#
# ### 🚀 Real-World Lunar Ambitions (as of 2024)
#
# While there’s no Luna City yet, several space agencies and organizations are actively working toward establishing a **permanent human presence on the Moon**, which could eventually evolve into something resembling a city.
#
# #### Key Projects & Goals:
#
# 1. **NASA’s Artemis Program**
#    - Goal: Return humans to the Moon by the mid-2020s (Artemis III)
#    - Establish the **Artemis Base Camp** near the lunar south pole
#    - Includes habitats, rovers, and a small space station in lunar orbit called **Gateway**
#
# 2. **China’s International Lunar Research Station (ILRS)**
#    - Planned with partners like Russia
#    - Targeting the Moon’s south pole by the 2030s
#    - Designed to support long-term scientific research and potential habitation
#
# 3. **Private Companies**
#    - SpaceX, Blue Origin, and others are developing lunar landers and infrastructure
#    - Could support tourism, mining, and construction of habitats
#
# 4. **European Space Agency (ESA) – “Moon Village” Concept**
#    - Not a single city, but a collaborative international settlement
#    - Envisions shared lunar infrastructure open to all nations
#
# ---
#
# ### 🏗️ Where Might a Real "Luna City" Be Built?
#
# Potential locations include:
# - **Lunar South Pole**: Rich in water ice (critical for life support and fuel)
# - **Peaks of Eternal Light**: Areas receiving near-constant sunlight for solar power
# - **Lava Tubes**: Natural underground tunnels that could shield inhabitants from radiation and micrometeorites
#
# ---
#
# ### 🧑‍🚀 Challenges to Building Luna City
#
# - **Extreme temperatures**: From -173°C (-280°F) at night to 127°C (260°F) during day
# - **Radiation**: No protective atmosphere or magnetic field
# - **Low gravity**: 1/6th of Earth’s—long-term health effects unknown
# - **Life support**: Need for closed-loop air, water, and food systems
# - **Cost**: Launching materials from Earth is extremely expensive
#
# Solutions may involve:
# - 3D printing habitats using lunar regolith (soil)
# - Mining water ice for oxygen and hydrogen (fuel)
# - Growing food in controlled environments
#
# ---
#
# ### 📅 When Could Luna City Become Reality?
#
# Most experts estimate:
# - **2030s–2040s**: First semi-permanent bases with rotating crews
# - **2100 and beyond**: Potential for larger settlements with hundreds or thousands of people—if technology, funding, and international cooperation align
#
# ---
#
# ### In Summary
#
# **Luna City** is not real today—but it represents a powerful vision for humanity’s future in space. While we’re still decades away from a true lunar metropolis, active missions and global interest make it increasingly plausible that **the first foundations of a lunar city will be laid within this century.**
#
# Would you like a speculative blueprint of what Luna City might look like in 2100? 🌌🌕
