# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

import os
from langchain.chat_models import init_chat_model
model = init_chat_model(model="qwen-plus", model_provider="openai", base_url=os.getenv("ALIBABA_BASE_URL"))

agent = create_agent(
    model=model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# My training data cutoff time is October 2024, so my knowledge is up to date until that point. If you have specific questions, I will do my best to provide information based on the data available up to that time.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient


tavily_client = TavilyClient()
@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# ---------------------------------------------------------------------------
# MissingAPIKeyError                        Traceback (most recent call last)
# Cell In[1], line 5
#       2 from typing import Dict, Any
#       3 from tavily import TavilyClient
# ----> 5 tavily_client = TavilyClient()
#       7 @tool
#       8 def web_search(query: str) -> Dict[str, Any]:
#      10     """Search the web for information"""
#
# File f:\env\miniconda\envs\python3.11\Lib\site-packages\tavily\client.py:27, in TavilyClient.__init__(self, api_key, base_url, timeout)
#      25 self.api_key = api_key or os.getenv("TAVILY_API_KEY")
#      26 if not self.api_key:
# ---> 27     raise MissingAPIKeyError(
#      28         "API key is required. Set TAVILY_API_KEY environment variable or pass api_key parameter")
#      30 self.base_url = base_url
#      31 self.timeout = min(timeout, 120)
#
# MissingAPIKeyError: API key is required. Set TAVILY_API_KEY environment variable or pass api_key parameter

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
