# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI


model = ChatOpenAI(model="qwen-plus",base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",temperature=0.7)
agent = create_agent(
    model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='1faf9303-01d4-4311-88bf-f302efe413f6'),
#               AIMessage(content='Hello Seán! 🌿 It’s lovely to meet you—and what a wonderful choice: green is such a vibrant, life-affirming colour—symbolising growth, harmony, and renewal. Whether it’s the deep emerald of forest shadows, the fresh mint of spring leaves, or the calming sage of a quiet meadow, green has a special way of grounding and inspiring. Do you have a particular shade of green you love most, or a favourite memory tied to it? 😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 20, 'total_tokens': 120, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'qwen-plus', 'system_fingerprint': None, 'id': 'chatcmpl-0aedea5b-e61e-9901-b293-f1721f4b9572', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c13aa-8c84-7172-8599-d0e83339049e-0', usage_metadata={'input_tokens': 20, 'output_tokens': 100, 'total_tokens': 120, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='662fdd47-8d18-4f41-8be4-1bb90b95a1fd'),
#               AIMessage(content='I don’t have access to your personal preferences—including your favourite colour—since I don’t store or recall past interactions or personal data. 😊  \nIf you’d like, you can tell me what it is—I’d love to chat about it! 🌈', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 14, 'total_tokens': 67, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'qwen-plus', 'system_fingerprint': None, 'id': 'chatcmpl-1ac12c68-d3b6-9b44-88cd-5654e0f78d5f', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c13aa-c2ff-7271-9a41-4a4dbb458a28-0', usage_metadata={'input_tokens': 14, 'output_tokens': 53, 'total_tokens': 67, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='930914d8-1347-43f3-a15b-319c6e583968'),
#               AIMessage(content="Hello, Seán! 🌿 It's lovely to meet you — and what a wonderful choice: green is such a vibrant, life-affirming colour. Whether it’s the freshness of spring leaves, the calm of a forest glade, or the energy of emerald or lime, green carries so much meaning — growth, harmony, renewal. Do you have a particular shade of green you love most, or does it remind you of a special place or memory? 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 20, 'total_tokens': 117, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'qwen-plus', 'system_fingerprint': None, 'id': 'chatcmpl-56911e6c-38a1-9fec-a1f9-1963a9640c32', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c13ab-c515-77f2-9b5f-356216251d0e-0', usage_metadata={'input_tokens': 20, 'output_tokens': 97, 'total_tokens': 117, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
